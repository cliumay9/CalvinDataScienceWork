# %%
# %matplotlib inline

import numpy as np 
import matplotlib as mpl 
#mpl.use('agg')
import matplotlib.pyplot as plt 

np.random.seed(129)

data_1 = np.random.normal(62, 13, 60)
data_2 = np.random.normal(55, 9, 60)


combined_data = [data_1, data_2]

# figure instance
fig = plt.figure(1, figsize=(9, 9))

# axes instance
ax = fig.add_subplot(111)

# draw boxplot
bxp = ax.boxplot(combined_data)

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix as spm

cars = pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Auto.csv")

_ = spm(cars[['displacement', 'weight', 'mpg']], figsize=(10, 10))

# %%
import numpy as np 
import matplotlib as mpl 
#mpl.use('agg')
import matplotlib.pyplot as plt 

np.random.seed(129)

data_3 = np.random.normal(68, 9, 60)
data_4 = np.random.normal(44, 4, 60)

combined_data_2 = [data_3, data_4]

fig = plt.figure(2, figsize=(9, 9))

# axes instance
ax1 = fig.add_subplot(111)

bxp1= ax1.boxplot(combined_data_2)

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix as spm

cars1= pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Auto.csv")
_1 = spm(cars1[['displacement', 'weight', 'mpg']], figsize=(10, 10))
